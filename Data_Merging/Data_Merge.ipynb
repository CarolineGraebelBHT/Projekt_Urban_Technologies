# %%
# building a map
import pandas as pd
import os
import geopandas as gpd
from shapely import wkt
import geopandas as gpd
import requests

# %%
# import data
current_dir = os.getcwd()

# Construct the path to the 'data' directory relative to the current directory
data_dir = os.path.join(current_dir, '..', 'data')

# Access a specific file
map12_df = pd.read_csv(os.path.join(data_dir, 'Secondary_Primary_Streets.csv'))
map3r_df = pd.read_csv(os.path.join(data_dir, 'Tertiary_Residential_Streets.csv'))
bike_df = pd.read_csv(os.path.join(data_dir, 'Infravelo+Location.csv'))

# %%
map3r_df
# Out:
#            highway  lanes  lit maxspeed                  name oneway     ref  \
# 0      residential    NaN  NaN      NaN   Ella-Augustin-Platz    NaN     NaN
# 1      residential    NaN  yes      NaN            Essenplatz    NaN     NaN
# 2      residential    NaN  yes       30      Fritz-Lang-Platz    yes     NaN
# 3      residential    NaN  yes       50            Waldstraße    NaN     NaN
# 4      residential    NaN  yes       30  Ursula-Goetze-Straße    NaN     NaN
# ...            ...    ...  ...      ...                   ...    ...     ...
# 46428     tertiary    2.0  yes       50       Märkische Allee    NaN     NaN
# 46429     tertiary    2.0  NaN       50    Genshagener Straße    NaN  K 7241
# 46430  residential    NaN  yes       30         Sattlerstraße     no     NaN
# 46431  residential    NaN  yes       30         Sattlerstraße     no     NaN
# 46432  residential    NaN  NaN       30         Zum Heidefeld    NaN     NaN
#
#       smoothness                                           geometry
# 0            NaN  POLYGON ((13.2181527 52.5701596, 13.2184018 52...
# 1           good  POLYGON ((13.5913761 52.4600805, 13.5913155 52...
# 2           good  POLYGON ((13.6027786 52.5378726, 13.6026875 52...
# 3           good  LINESTRING (13.6052427 52.3734412, 13.6052763 ...
# 4           good  LINESTRING (13.531363 52.4926293, 13.5313613 5...
# ...          ...                                                ...
# 46428        NaN  LINESTRING (13.2885203 52.3514517, 13.2885668 ...
# 46429        NaN  LINESTRING (13.303733 52.3466163, 13.3034641 5...
# 46430       good  LINESTRING (13.4844028 52.42317, 13.4844427 52...
# 46431       good  LINESTRING (13.4843647 52.4231874, 13.4844028 ...
# 46432        NaN  LINESTRING (13.3042205 52.3495428, 13.3052338 ...
#
# [46433 rows x 9 columns]

# %%
# merge maps
map_df = pd.concat([map12_df, map3r_df], ignore_index = True)
map_df
# Out:
#            highway  lanes  lit maxspeed                name oneway      ref  \
# 0          primary    3.0  yes     50.0   Frankfurter Allee    yes  B 1;B 5
# 1        secondary    NaN  yes     30.0           Seestraße    NaN    L 401
# 2        secondary    NaN  yes     30.0        Goethestraße    NaN    L 401
# 3        secondary    NaN  yes     50.0          Dorfstraße    NaN    L 402
# 4        secondary    2.0  yes     50.0         Hauptstraße    NaN      NaN
# ...            ...    ...  ...      ...                 ...    ...      ...
# 64240     tertiary    2.0  yes       50     Märkische Allee    NaN      NaN
# 64241     tertiary    2.0  NaN       50  Genshagener Straße    NaN   K 7241
# 64242  residential    NaN  yes       30       Sattlerstraße     no      NaN
# 64243  residential    NaN  yes       30       Sattlerstraße     no      NaN
# 64244  residential    NaN  NaN       30       Zum Heidefeld    NaN      NaN
#
#          smoothness                                           geometry
# 0         excellent  LINESTRING (13.4541952 52.5157145, 13.4543122 ...
# 1               bad  LINESTRING (13.6370044 52.3692569, 13.636938 5...
# 2               bad  LINESTRING (13.6318938 52.352067, 13.6318822 5...
# 3      intermediate  LINESTRING (13.6167013 52.341313, 13.6166233 5...
# 4              good  LINESTRING (13.3728224 52.5933399, 13.3728054 ...
# ...             ...                                                ...
# 64240           NaN  LINESTRING (13.2885203 52.3514517, 13.2885668 ...
# 64241           NaN  LINESTRING (13.303733 52.3466163, 13.3034641 5...
# 64242          good  LINESTRING (13.4844028 52.42317, 13.4844427 52...
# 64243          good  LINESTRING (13.4843647 52.4231874, 13.4844028 ...
# 64244           NaN  LINESTRING (13.3042205 52.3495428, 13.3052338 ...
#
# [64245 rows x 9 columns]

# %%
map_df = map_df.rename(columns = {"name": "streetname"})
map_df
# Out:
#            highway  lanes  lit maxspeed          streetname oneway      ref  \
# 0          primary    3.0  yes     50.0   Frankfurter Allee    yes  B 1;B 5
# 1        secondary    NaN  yes     30.0           Seestraße    NaN    L 401
# 2        secondary    NaN  yes     30.0        Goethestraße    NaN    L 401
# 3        secondary    NaN  yes     50.0          Dorfstraße    NaN    L 402
# 4        secondary    2.0  yes     50.0         Hauptstraße    NaN      NaN
# ...            ...    ...  ...      ...                 ...    ...      ...
# 64240     tertiary    2.0  yes       50     Märkische Allee    NaN      NaN
# 64241     tertiary    2.0  NaN       50  Genshagener Straße    NaN   K 7241
# 64242  residential    NaN  yes       30       Sattlerstraße     no      NaN
# 64243  residential    NaN  yes       30       Sattlerstraße     no      NaN
# 64244  residential    NaN  NaN       30       Zum Heidefeld    NaN      NaN
#
#          smoothness                                           geometry
# 0         excellent  LINESTRING (13.4541952 52.5157145, 13.4543122 ...
# 1               bad  LINESTRING (13.6370044 52.3692569, 13.636938 5...
# 2               bad  LINESTRING (13.6318938 52.352067, 13.6318822 5...
# 3      intermediate  LINESTRING (13.6167013 52.341313, 13.6166233 5...
# 4              good  LINESTRING (13.3728224 52.5933399, 13.3728054 ...
# ...             ...                                                ...
# 64240           NaN  LINESTRING (13.2885203 52.3514517, 13.2885668 ...
# 64241           NaN  LINESTRING (13.303733 52.3466163, 13.3034641 5...
# 64242          good  LINESTRING (13.4844028 52.42317, 13.4844427 52...
# 64243          good  LINESTRING (13.4843647 52.4231874, 13.4844028 ...
# 64244           NaN  LINESTRING (13.3042205 52.3495428, 13.3052338 ...
#
# [64245 rows x 9 columns]

# %%
# show data points where the streetname is missing
problem_df = map_df[map_df["streetname"].isnull()].copy().reset_index(drop=True)
problem_df
# Out:
#          highway  lanes  lit maxspeed streetname oneway    ref    smoothness  \
# 0      secondary    4.0  yes     50.0        NaN    NaN    NaN  intermediate
# 1      secondary    2.0  yes     40.0        NaN    NaN    NaN           NaN
# 2      secondary    2.0  NaN     70.0        NaN     no  L 305          good
# 3      secondary    5.0  yes     50.0        NaN    NaN    NaN           NaN
# 4      secondary    5.0  yes     50.0        NaN    NaN    NaN           NaN
# ..           ...    ...  ...      ...        ...    ...    ...           ...
# 787  residential    NaN  yes       30        NaN    yes    NaN           NaN
# 788  residential    NaN  NaN       30        NaN    NaN    NaN           NaN
# 789     tertiary    2.0   no       50        NaN    NaN    NaN           NaN
# 790  residential    NaN  NaN      NaN        NaN    NaN    NaN           NaN
# 791  residential    NaN  NaN      NaN        NaN    NaN    NaN     excellent
#
#                                               geometry
# 0    LINESTRING (13.3285254 52.5329513, 13.3283382 ...
# 1    LINESTRING (13.2723709 52.5004532, 13.2723539 ...
# 2    LINESTRING (13.4089058 52.6620481, 13.409994 5...
# 3    LINESTRING (13.3002424 52.5220927, 13.3002606 ...
# 4    LINESTRING (13.2997982 52.5213681, 13.2999295 ...
# ..                                                 ...
# 787  LINESTRING (13.4127849 52.5190237, 13.4127486 ...
# 788  LINESTRING (13.1209996 52.6016583, 13.121177 5...
# 789  LINESTRING (13.1502178 52.5066292, 13.1499788 ...
# 790  LINESTRING (13.3425593 52.4774698, 13.3424508 ...
# 791  LINESTRING (13.7473635 52.6362853, 13.7474244 ...
#
# [792 rows x 9 columns]

# %%
# drop data point where streetname is missing
map_df = map_df[map_df["streetname"].notnull()]
map_df
# Out:
#            highway  lanes  lit maxspeed          streetname oneway      ref  \
# 0          primary    3.0  yes     50.0   Frankfurter Allee    yes  B 1;B 5
# 1        secondary    NaN  yes     30.0           Seestraße    NaN    L 401
# 2        secondary    NaN  yes     30.0        Goethestraße    NaN    L 401
# 3        secondary    NaN  yes     50.0          Dorfstraße    NaN    L 402
# 4        secondary    2.0  yes     50.0         Hauptstraße    NaN      NaN
# ...            ...    ...  ...      ...                 ...    ...      ...
# 64240     tertiary    2.0  yes       50     Märkische Allee    NaN      NaN
# 64241     tertiary    2.0  NaN       50  Genshagener Straße    NaN   K 7241
# 64242  residential    NaN  yes       30       Sattlerstraße     no      NaN
# 64243  residential    NaN  yes       30       Sattlerstraße     no      NaN
# 64244  residential    NaN  NaN       30       Zum Heidefeld    NaN      NaN
#
#          smoothness                                           geometry
# 0         excellent  LINESTRING (13.4541952 52.5157145, 13.4543122 ...
# 1               bad  LINESTRING (13.6370044 52.3692569, 13.636938 5...
# 2               bad  LINESTRING (13.6318938 52.352067, 13.6318822 5...
# 3      intermediate  LINESTRING (13.6167013 52.341313, 13.6166233 5...
# 4              good  LINESTRING (13.3728224 52.5933399, 13.3728054 ...
# ...             ...                                                ...
# 64240           NaN  LINESTRING (13.2885203 52.3514517, 13.2885668 ...
# 64241           NaN  LINESTRING (13.303733 52.3466163, 13.3034641 5...
# 64242          good  LINESTRING (13.4844028 52.42317, 13.4844427 52...
# 64243          good  LINESTRING (13.4843647 52.4231874, 13.4844028 ...
# 64244           NaN  LINESTRING (13.3042205 52.3495428, 13.3052338 ...
#
# [63453 rows x 9 columns]

# %%
map_df = map_df.drop_duplicates()
map_df
# Out:
#            highway  lanes  lit maxspeed          streetname oneway      ref  \
# 0          primary    3.0  yes     50.0   Frankfurter Allee    yes  B 1;B 5
# 1        secondary    NaN  yes     30.0           Seestraße    NaN    L 401
# 2        secondary    NaN  yes     30.0        Goethestraße    NaN    L 401
# 3        secondary    NaN  yes     50.0          Dorfstraße    NaN    L 402
# 4        secondary    2.0  yes     50.0         Hauptstraße    NaN      NaN
# ...            ...    ...  ...      ...                 ...    ...      ...
# 64240     tertiary    2.0  yes       50     Märkische Allee    NaN      NaN
# 64241     tertiary    2.0  NaN       50  Genshagener Straße    NaN   K 7241
# 64242  residential    NaN  yes       30       Sattlerstraße     no      NaN
# 64243  residential    NaN  yes       30       Sattlerstraße     no      NaN
# 64244  residential    NaN  NaN       30       Zum Heidefeld    NaN      NaN
#
#          smoothness                                           geometry
# 0         excellent  LINESTRING (13.4541952 52.5157145, 13.4543122 ...
# 1               bad  LINESTRING (13.6370044 52.3692569, 13.636938 5...
# 2               bad  LINESTRING (13.6318938 52.352067, 13.6318822 5...
# 3      intermediate  LINESTRING (13.6167013 52.341313, 13.6166233 5...
# 4              good  LINESTRING (13.3728224 52.5933399, 13.3728054 ...
# ...             ...                                                ...
# 64240           NaN  LINESTRING (13.2885203 52.3514517, 13.2885668 ...
# 64241           NaN  LINESTRING (13.303733 52.3466163, 13.3034641 5...
# 64242          good  LINESTRING (13.4844028 52.42317, 13.4844427 52...
# 64243          good  LINESTRING (13.4843647 52.4231874, 13.4844028 ...
# 64244           NaN  LINESTRING (13.3042205 52.3495428, 13.3052338 ...
#
# [63449 rows x 9 columns]

# %%
map_df[map_df["highway"] == "residential"]
# Out:
#            highway  lanes  lit maxspeed             streetname oneway  ref  \
# 17812  residential    NaN  NaN      NaN    Ella-Augustin-Platz    NaN  NaN
# 17813  residential    NaN  yes      NaN             Essenplatz    NaN  NaN
# 17814  residential    NaN  yes       30       Fritz-Lang-Platz    yes  NaN
# 17815  residential    NaN  yes       50             Waldstraße    NaN  NaN
# 17816  residential    NaN  yes       30   Ursula-Goetze-Straße    NaN  NaN
# ...            ...    ...  ...      ...                    ...    ...  ...
# 64238  residential    NaN  yes       30             Rue Racine    NaN  NaN
# 64239  residential    NaN  yes       30  An der Korsopromenade    NaN  NaN
# 64242  residential    NaN  yes       30          Sattlerstraße     no  NaN
# 64243  residential    NaN  yes       30          Sattlerstraße     no  NaN
# 64244  residential    NaN  NaN       30          Zum Heidefeld    NaN  NaN
#
#       smoothness                                           geometry
# 17812        NaN  POLYGON ((13.2181527 52.5701596, 13.2184018 52...
# 17813       good  POLYGON ((13.5913761 52.4600805, 13.5913155 52...
# 17814       good  POLYGON ((13.6027786 52.5378726, 13.6026875 52...
# 17815       good  LINESTRING (13.6052427 52.3734412, 13.6052763 ...
# 17816       good  LINESTRING (13.531363 52.4926293, 13.5313613 5...
# ...          ...                                                ...
# 64238        NaN  LINESTRING (13.3159571 52.6019258, 13.3157936 ...
# 64239       good  LINESTRING (13.6242563 52.3365501, 13.6247031 ...
# 64242       good  LINESTRING (13.4844028 52.42317, 13.4844427 52...
# 64243       good  LINESTRING (13.4843647 52.4231874, 13.4844028 ...
# 64244        NaN  LINESTRING (13.3042205 52.3495428, 13.3052338 ...
#
# [37974 rows x 9 columns]

# %%
bike_df = bike_df.rename(columns = {"title": "streetname"})
bike_df
# Out:
#               id                        streetname  \
# 0     9080038002  A-Schweitzer-Gymnasium Gymnasium
# 1     9100031042                 Adorfer Straße  8
# 2     9060111001                 Albrechtstraße 49
# 3     9060092029                 Albrechtstraße 81
# 4     9100031023          Alfred-Döblin-Straße 2 A
# ...          ...                               ...
# 1984      100345                     Schloß­straße
# 1985      100349                   Schlüter­straße
# 1986      100335                  Werbellin­straße
# 1987      100338                    Wichert­straße
# 1988      100340                    Wisbyer Straße
#
#                                                    link  \
# 0     https://www.infravelo.de/projekt/a-schweitzer-...
# 1     https://www.infravelo.de/projekt/adorfer-stras...
# 2     https://www.infravelo.de/projekt/albrechtstras...
# 3     https://www.infravelo.de/projekt/albrechtstras...
# 4     https://www.infravelo.de/projekt/alfred-doebli...
# ...                                                 ...
# 1984   https://www.infravelo.de/projekt/schlossstrasse/
# 1985  https://www.infravelo.de/projekt/schlueterstra...
# 1986  https://www.infravelo.de/projekt/werbellinstra...
# 1987   https://www.infravelo.de/projekt/wichertstrasse/
# 1988  https://www.infravelo.de/projekt/wisbyer-strasse/
#
#                         district                   type                name  \
# 0                       Neukölln            Anlehnbügel  Anzahl Stellplätze
# 1            Marzahn-Hellersdorf            Anlehnbügel  Anzahl Stellplätze
# 2            Steglitz-Zehlendorf            Anlehnbügel  Anzahl Stellplätze
# 3            Steglitz-Zehlendorf            Anlehnbügel  Anzahl Stellplätze
# 4            Marzahn-Hellersdorf            Anlehnbügel  Anzahl Stellplätze
# ...                          ...                    ...                 ...
# 1984         Steglitz-Zehlendorf  Grüner Seitenstreifen        Straßenseite
# 1985  Charlottenburg-Wilmersdorf  Grüner Seitenstreifen        Straßenseite
# 1986                    Neukölln  Grüner Seitenstreifen        Straßenseite
# 1987                      Pankow  Grüner Seitenstreifen        Straßenseite
# 1988                      Pankow  Grüner Seitenstreifen        Straßenseite
#
#            value function                       location
# 0             30  parking                            NaN
# 1              6  parking  POINT (52.5320026 13.6072718)
# 2              4  parking  POINT (52.4483762 13.3391646)
# 3             16  parking  POINT (52.4494241 13.3384682)
# 4              8  parking  POINT (52.5521667 13.5512789)
# ...          ...      ...                            ...
# 1984  Beidseitig     road   POINT (52.461481 13.3250946)
# 1985  Beidseitig     road  POINT (52.5052562 13.3174056)
# 1986  Beidseitig     road  POINT (52.4776454 13.4263773)
# 1987  Beidseitig     road   POINT (52.5470187 13.424838)
# 1988  Beidseitig     road  POINT (52.5525784 13.4265126)
#
# [1989 rows x 9 columns]

# %%
bike_df[bike_df["location"].isnull()]
# Out:
#               id                                         streetname  \
# 0     9080038002                   A-Schweitzer-Gymnasium Gymnasium
# 5     9100057004                  Alice-Salomon-Platz ggü. Rathaus
# 21    9010102108                   Alt-Moabit / Elberfelder Straße
# 26    9110077010                          Alte Frankfurter Allee  -
# 27    9110077011                         Alte Frankfurter Allee 250
# ...          ...                                                ...
# 1962      100627  Mobile gesicherte Abstellanlagen mit dem Sonde...
# 1964      100091                      Neubau Wasserweg am Spreepark
# 1965      100588  Gesicherte Radabstellanlage am Rathaus Schöneberg
# 1972      100334                 Habelschwer­dter Allee/Thiel­allee
# 1978      100612              Kreuzung Alt-Biesdorf/Märkische Allee
#
#                                                    link              district  \
# 0     https://www.infravelo.de/projekt/a-schweitzer-...              Neukölln
# 5     https://www.infravelo.de/projekt/alice-salomon...   Marzahn-Hellersdorf
# 21    https://www.infravelo.de/projekt/alt-moabit-el...                 Mitte
# 26    https://www.infravelo.de/projekt/alte-frankfur...           Lichtenberg
# 27    https://www.infravelo.de/projekt/alte-frankfur...           Lichtenberg
# ...                                                 ...                   ...
# 1962  https://www.infravelo.de/projekt/mobile-gesich...              Neukölln
# 1964  https://www.infravelo.de/projekt/neubau-wasser...      Treptow-Köpenick
# 1965  https://www.infravelo.de/projekt/gesicherte-ra...  Tempelhof-Schöneberg
# 1972  https://www.infravelo.de/projekt/habelschwerdt...   Steglitz-Zehlendorf
# 1978  https://www.infravelo.de/projekt/kreuzung-alt-...   Marzahn-Hellersdorf
#
#                        type                name       value function location
# 0               Anlehnbügel  Anzahl Stellplätze          30  parking      NaN
# 5               Anlehnbügel  Anzahl Stellplätze          16  parking      NaN
# 21              Anlehnbügel  Anzahl Stellplätze          16  parking      NaN
# 26              Anlehnbügel  Anzahl Stellplätze          32  parking      NaN
# 27              Anlehnbügel  Anzahl Stellplätze          20  parking      NaN
# ...                     ...                 ...         ...      ...      ...
# 1962             Fahrradbox         Stellplätze          16  parking      NaN
# 1964              Sonderweg       Streckenlänge       320 m     road      NaN
# 1965             Fahrradbox         Stellplätze          64  parking      NaN
# 1972  Grüner Seitenstreifen        Straßenseite  Beidseitig     road      NaN
# 1978  Grüner Seitenstreifen        Straßenseite  Beidseitig     road      NaN
#
# [312 rows x 9 columns]

# %%
# what kind of streets don't have a location info?
bike_df[bike_df["location"].isnull()]["streetname"].value_counts()
# Out:
# streetname
# Klever Straße / Eulerstraße                       7
# S Zehlendorf KL. Teltower D. (vor Blume 2000)     3
# Lückenschluss Müllerstraße                        2
# Möckernstraße (Ost­seite)                         2
# Lichterfelde Ost Vorplatz/Jungfernstieg           2
#                                                  ..
# Köpenzeile 117, 123, 125                          1
# Königstr./Martin-Buber-Str.                       1
# Knorrpromenade / Krossener Straße                 1
# Kiehufer Eingang 2 62                             1
# Kreuzung Alt-Biesdorf/Märkische Allee             1
# Name: count, Length: 297, dtype: int64

# %%
test = map_df[map_df["streetname"] == "Alt-Moabit"]
test
# Out:
#            highway  lanes  lit maxspeed  streetname oneway  ref smoothness  \
# 104      secondary    2.0  yes     50.0  Alt-Moabit    yes  NaN       good
# 105      secondary    2.0  yes     50.0  Alt-Moabit    yes  NaN       good
# 472      secondary    2.0  yes     50.0  Alt-Moabit    yes  NaN  excellent
# 532      secondary    4.0  yes     50.0  Alt-Moabit    NaN  NaN       good
# 602      secondary    NaN  yes     50.0  Alt-Moabit    yes  NaN       good
# ...            ...    ...  ...      ...         ...    ...  ...        ...
# 49120  residential    NaN  yes       50  Alt-Moabit    NaN  NaN  excellent
# 60915     tertiary    NaN  yes       50  Alt-Moabit    yes  NaN        NaN
# 63204     tertiary    2.0  yes       50  Alt-Moabit    yes  NaN       good
# 63514     tertiary    2.0  yes       50  Alt-Moabit    yes  NaN       good
# 63515     tertiary    2.0  yes       50  Alt-Moabit    yes  NaN       good
#
#                                                 geometry
# 104    LINESTRING (13.3551897 52.5238581, 13.3550696 ...
# 105    LINESTRING (13.339814 52.5257573, 13.3396931 5...
# 472    LINESTRING (13.3349737 52.524647, 13.3351584 5...
# 532    LINESTRING (13.3341421 52.5245338, 13.3340876 ...
# 602    LINESTRING (13.3429737 52.5254284, 13.3427802 ...
# ...                                                  ...
# 49120  LINESTRING (13.3349466 52.5247479, 13.3349737 ...
# 60915  LINESTRING (13.3597741 52.5234627, 13.359575 5...
# 63204  LINESTRING (13.3594317 52.5232858, 13.3595145 ...
# 63514  LINESTRING (13.3630432 52.5230575, 13.362888 5...
# 63515  LINESTRING (13.3624774 52.5229029, 13.3626278 ...
#
# [92 rows x 9 columns]

# %%
def process_linestring(linestring):
    cleaned_string = linestring[12:-1]
    loc_list = cleaned_string.split(',')
    coordinates = []
    for pair in loc_list:
        lon, lat = map(float, pair.split())
        coordinates.append((lon, lat))
    return coordinates

geo_list = test["geometry"].to_list()

loc_list = []
for i in range(len(geo_list)):
    transformed_geo = process_linestring(geo_list[i])
    loc_list.append(transformed_geo)

test["altgeom"] = loc_list

test
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_11548\1684962230.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["altgeom"] = loc_list
#            highway  lanes  lit maxspeed  streetname oneway  ref smoothness  \
# 104      secondary    2.0  yes     50.0  Alt-Moabit    yes  NaN       good
# 105      secondary    2.0  yes     50.0  Alt-Moabit    yes  NaN       good
# 472      secondary    2.0  yes     50.0  Alt-Moabit    yes  NaN  excellent
# 532      secondary    4.0  yes     50.0  Alt-Moabit    NaN  NaN       good
# 602      secondary    NaN  yes     50.0  Alt-Moabit    yes  NaN       good
# ...            ...    ...  ...      ...         ...    ...  ...        ...
# 49120  residential    NaN  yes       50  Alt-Moabit    NaN  NaN  excellent
# 60915     tertiary    NaN  yes       50  Alt-Moabit    yes  NaN        NaN
# 63204     tertiary    2.0  yes       50  Alt-Moabit    yes  NaN       good
# 63514     tertiary    2.0  yes       50  Alt-Moabit    yes  NaN       good
# 63515     tertiary    2.0  yes       50  Alt-Moabit    yes  NaN       good
#
#                                                 geometry  \
# 104    LINESTRING (13.3551897 52.5238581, 13.3550696 ...
# 105    LINESTRING (13.339814 52.5257573, 13.3396931 5...
# 472    LINESTRING (13.3349737 52.524647, 13.3351584 5...
# 532    LINESTRING (13.3341421 52.5245338, 13.3340876 ...
# 602    LINESTRING (13.3429737 52.5254284, 13.3427802 ...
# ...                                                  ...
# 49120  LINESTRING (13.3349466 52.5247479, 13.3349737 ...
# 60915  LINESTRING (13.3597741 52.5234627, 13.359575 5...
# 63204  LINESTRING (13.3594317 52.5232858, 13.3595145 ...
# 63514  LINESTRING (13.3630432 52.5230575, 13.362888 5...
# 63515  LINESTRING (13.3624774 52.5229029, 13.3626278 ...
#
#                                                  altgeom
# 104    [(13.3551897, 52.5238581), (13.3550696, 52.523...
# 105    [(13.339814, 52.5257573), (13.3396931, 52.5257...
# 472    [(13.3349737, 52.524647), (13.3351584, 52.5246...
# 532    [(13.3341421, 52.5245338), (13.3340876, 52.524...
# 602    [(13.3429737, 52.5254284), (13.3427802, 52.525...
# ...                                                  ...
# 49120  [(13.3349466, 52.5247479), (13.3349737, 52.524...
# 60915  [(13.3597741, 52.5234627), (13.359575, 52.5234...
# 63204  [(13.3594317, 52.5232858), (13.3595145, 52.523...
# 63514  [(13.3630432, 52.5230575), (13.362888, 52.5230...
# 63515  [(13.3624774, 52.5229029), (13.3626278, 52.522...
#
# [92 rows x 10 columns]

# %%
road_df = bike_df[bike_df["function"] == "road"]
road_df
# Out:
#            id                                streetname  \
# 1727  9050027            Ferdinand-Frie­dens­burg-Platz
# 1728  9080043              Weserstraße (Bauabschnitt 2)
# 1730  9020013                           Karl-Marx-Allee
# 1734  9020137                        Schlesische Straße
# 1735  9010022  Spree-Rad- und Wander­weg (Bezirk Mitte)
# ...       ...                                       ...
# 1984   100345                             Schloß­straße
# 1985   100349                           Schlüter­straße
# 1986   100335                          Werbellin­straße
# 1987   100338                            Wichert­straße
# 1988   100340                            Wisbyer Straße
#
#                                                    link  \
# 1727  https://www.infravelo.de/projekt/ferdinand-fri...
# 1728  https://www.infravelo.de/projekt/weserstrasse-...
# 1730  https://www.infravelo.de/projekt/karl-marx-allee/
# 1734  https://www.infravelo.de/projekt/schlesische-s...
# 1735  https://www.infravelo.de/projekt/spree-rad-und...
# ...                                                 ...
# 1984   https://www.infravelo.de/projekt/schlossstrasse/
# 1985  https://www.infravelo.de/projekt/schlueterstra...
# 1986  https://www.infravelo.de/projekt/werbellinstra...
# 1987   https://www.infravelo.de/projekt/wichertstrasse/
# 1988  https://www.infravelo.de/projekt/wisbyer-strasse/
#
#                         district                         type           name  \
# 1727                     Spandau    Baulich getrennter Radweg  Streckenlänge
# 1728                    Neukölln                Fahrradstraße  Streckenlänge
# 1730    Friedrichshain-Kreuzberg    Baulich getrennter Radweg         Fläche
# 1734    Friedrichshain-Kreuzberg  Geschützter Radfahrstreifen  Streckenlänge
# 1735                       Mitte                Fahrradstraße  Streckenlänge
# ...                          ...                          ...            ...
# 1984         Steglitz-Zehlendorf        Grüner Seitenstreifen   Straßenseite
# 1985  Charlottenburg-Wilmersdorf        Grüner Seitenstreifen   Straßenseite
# 1986                    Neukölln        Grüner Seitenstreifen   Straßenseite
# 1987                      Pankow        Grüner Seitenstreifen   Straßenseite
# 1988                      Pankow        Grüner Seitenstreifen   Straßenseite
#
#            value function                                       location
# 1727       540 m     road          POINT (52.539277350000006 13.2320894)
# 1728       590 m     road                                            NaN
# 1730    3.750 m²     road                 POINT (52.51721425 13.4406797)
# 1734       732 m     road  POINT (52.500229233625845 13.443597190626589)
# 1735       522 m     road                                            NaN
# ...          ...      ...                                            ...
# 1984  Beidseitig     road                   POINT (52.461481 13.3250946)
# 1985  Beidseitig     road                  POINT (52.5052562 13.3174056)
# 1986  Beidseitig     road                  POINT (52.4776454 13.4263773)
# 1987  Beidseitig     road                   POINT (52.5470187 13.424838)
# 1988  Beidseitig     road                  POINT (52.5525784 13.4265126)
#
# [203 rows x 9 columns]

# %%
map_bikeroad_df = map_df.merge(road_df, on = "streetname", how = "outer")
map_bikeroad_df
# Out:
#            highway  lanes  lit maxspeed           streetname oneway  ref  \
# 0      residential    NaN  yes      NaN  AEG-Siedlung Heimat    NaN  NaN
# 1      residential    NaN  yes       30  AEG-Siedlung Heimat    NaN  NaN
# 2      residential    NaN  yes       30      Aachener Straße    NaN  NaN
# 3      residential    NaN  yes       30      Aachener Straße    NaN  NaN
# 4      residential    NaN  yes       30      Aachener Straße    NaN  NaN
# ...            ...    ...  ...      ...                  ...    ...  ...
# 63975  residential    NaN  yes       30             Übergang    NaN  NaN
# 63976  residential    NaN  yes       30             Übergang    NaN  NaN
# 63977  residential    NaN  yes       30        Üderseestraße    NaN  NaN
# 63978  residential    NaN  yes       30        Üderseestraße    NaN  NaN
# 63979  residential    NaN  yes       30        Üderseestraße    NaN  NaN
#
#       smoothness                                           geometry  id link  \
# 0            NaN  LINESTRING (13.3478331 52.6098004, 13.347076 5... NaN  NaN
# 1            NaN  LINESTRING (13.347866 52.608813, 13.347076 52.... NaN  NaN
# 2            NaN  LINESTRING (13.3189287 52.4813095, 13.318873 5... NaN  NaN
# 3            NaN  LINESTRING (13.3183653 52.4789371, 13.3181786 ... NaN  NaN
# 4            NaN  LINESTRING (13.3155418 52.4796441, 13.3155083 ... NaN  NaN
# ...          ...                                                ...  ..  ...
# 63975        NaN  LINESTRING (13.1594251 52.5417989, 13.1595362 ... NaN  NaN
# 63976        NaN  LINESTRING (13.1596394 52.5424059, 13.1596699 ... NaN  NaN
# 63977        NaN  LINESTRING (13.5182312 52.4813673, 13.5182181 ... NaN  NaN
# 63978        bad  LINESTRING (13.5196709 52.4826088, 13.5182312 ... NaN  NaN
# 63979        bad  LINESTRING (13.5180657 52.4812339, 13.5168025 ... NaN  NaN
#
#       district type name value function location
# 0          NaN  NaN  NaN   NaN      NaN      NaN
# 1          NaN  NaN  NaN   NaN      NaN      NaN
# 2          NaN  NaN  NaN   NaN      NaN      NaN
# 3          NaN  NaN  NaN   NaN      NaN      NaN
# 4          NaN  NaN  NaN   NaN      NaN      NaN
# ...        ...  ...  ...   ...      ...      ...
# 63975      NaN  NaN  NaN   NaN      NaN      NaN
# 63976      NaN  NaN  NaN   NaN      NaN      NaN
# 63977      NaN  NaN  NaN   NaN      NaN      NaN
# 63978      NaN  NaN  NaN   NaN      NaN      NaN
# 63979      NaN  NaN  NaN   NaN      NaN      NaN
#
# [63980 rows x 17 columns]

# %%
# For how many street segments do we have biking infrastructure? 
map_bikeroad_df[map_bikeroad_df["type"].notnull()]
# Out:
#            highway  lanes  lit maxspeed  \
# 141      secondary    2.0  yes     60.0
# 142        primary    3.0  yes     50.0
# 143        primary    3.0  NaN     50.0
# 144        primary    4.0  NaN     50.0
# 145        primary    1.0  yes     50.0
# ...            ...    ...  ...      ...
# 63571     tertiary    2.0  yes       50
# 63572  residential    NaN  yes       30
# 63595          NaN    NaN  NaN      NaN
# 63627          NaN    NaN  NaN      NaN
# 63925          NaN    NaN  NaN      NaN
#
#                                               streetname oneway    ref  \
# 141                                         Adlergestell    yes    NaN
# 142                                         Adlergestell    yes  B 96a
# 143                                         Adlergestell    yes  B 96a
# 144                                         Adlergestell    yes  B 96a
# 145                                         Adlergestell    yes    NaN
# ...                                                  ...    ...    ...
# 63571                                    Zingster Straße    NaN    NaN
# 63572                                    Zingster Straße    NaN    NaN
# 63595                                    Zionskirchplatz    NaN    NaN
# 63627                                    Zobtener Straße    NaN    NaN
# 63925  Zwischen Margaretenhöhe und Wartenberger Feldmark    NaN    NaN
#
#          smoothness                                           geometry  \
# 141            good  LINESTRING (13.6246701 52.3900407, 13.6248096 ...
# 142             NaN  LINESTRING (13.5555923 52.4258598, 13.555072 5...
# 143             NaN  LINESTRING (13.5548558 52.4261798, 13.5550558 ...
# 144             NaN  LINESTRING (13.5573941 52.4244641, 13.557521 5...
# 145             NaN  LINESTRING (13.5489618 52.4301167, 13.5491512 ...
# ...             ...                                                ...
# 63571  intermediate  LINESTRING (13.4986886 52.5685494, 13.4988107 ...
# 63572           NaN  LINESTRING (13.5025589 52.5652501, 13.502635 5...
# 63595           NaN                                                NaN
# 63627           NaN                                                NaN
# 63925           NaN                                                NaN
#
#               id                                               link  \
# 141    9090039.0     https://www.infravelo.de/projekt/adlergestell/
# 142    9090039.0     https://www.infravelo.de/projekt/adlergestell/
# 143    9090039.0     https://www.infravelo.de/projekt/adlergestell/
# 144    9090039.0     https://www.infravelo.de/projekt/adlergestell/
# 145    9090039.0     https://www.infravelo.de/projekt/adlergestell/
# ...          ...                                                ...
# 63571  9110079.0  https://www.infravelo.de/projekt/zingster-stra...
# 63572  9110079.0  https://www.infravelo.de/projekt/zingster-stra...
# 63595  9010035.0  https://www.infravelo.de/projekt/zionskirchplatz/
# 63627  9110045.0  https://www.infravelo.de/projekt/zobtener-stra...
# 63925  9110037.0  https://www.infravelo.de/projekt/zwischen-marg...
#
#                district                         type              name  \
# 141    Treptow-Köpenick  Geschützter Radfahrstreifen     Streckenlänge
# 142    Treptow-Köpenick  Geschützter Radfahrstreifen     Streckenlänge
# 143    Treptow-Köpenick  Geschützter Radfahrstreifen     Streckenlänge
# 144    Treptow-Köpenick  Geschützter Radfahrstreifen     Streckenlänge
# 145    Treptow-Köpenick  Geschützter Radfahrstreifen     Streckenlänge
# ...                 ...                          ...               ...
# 63571       Lichtenberg    Baulich getrennter Radweg     Streckenlänge
# 63572       Lichtenberg    Baulich getrennter Radweg     Streckenlänge
# 63595             Mitte        Verkehrsbeschilderung  Anzahl Wegweiser
# 63627       Lichtenberg                Fahrradstraße            Fläche
# 63925       Lichtenberg                 Mischverkehr     Streckenlänge
#
#         value function                               location
# 141     945 m     road         POINT (52.4273954 13.55306775)
# 142     945 m     road         POINT (52.4273954 13.55306775)
# 143     945 m     road         POINT (52.4273954 13.55306775)
# 144     945 m     road         POINT (52.4273954 13.55306775)
# 145     945 m     road         POINT (52.4273954 13.55306775)
# ...       ...      ...                                    ...
# 63571   299 m     road          POINT (52.5656901 13.5007932)
# 63572   299 m     road          POINT (52.5656901 13.5007932)
# 63595       2     road  POINT (52.5346033 13.403797262217864)
# 63627  250 m²     road          POINT (52.4990881 13.4849141)
# 63925   175 m     road                                    NaN
#
# [4633 rows x 17 columns]

# %%
# save bike road data merged with openstreet map data
map_bikeroad_df.to_csv("Bikeroad_Location.csv", index = False)
