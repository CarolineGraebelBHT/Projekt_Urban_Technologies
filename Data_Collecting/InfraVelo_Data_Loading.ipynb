# %%
import json
import pandas as pd
import urllib

# %%
"""This function reads in the data from the InfraVelo-API. For this, it needs to iterate through the pages and bring
variables in listed dictionaries in a form that they are json-formatted. The resulting object can be transformed
into a pandas dataframe."""
def get_data_infravelo(url, flat_data = []):
    response = urllib.request.urlopen(url)
    json_data = json.loads(response.read())

    for project in json_data["results"]:
        # extract relevant information from each project dictionary
        new_row = {
          "id": project["id"],
          "title": project["title"],
          "subtitle": project.get("subtitle", ""),
          "yearOfImplementation": project.get("yearOfImplementation", ""),  # Handle missing year
          "status": project.get("status", ""),
          "holder": project.get("holder", ""),
          "costs": project.get("costs", ""),
          "link": project.get("link", ""),
          "apiLink": project.get("apiLink", ""),
          "companyConstruction": project.get("companyConstruction", ""),
          "owner": project.get("owner", ""),
          "district": project["districts"][0]["name"] if project["districts"] else "",
          "dateStart": project.get("dateStart", ""),
          "dateEnd": project.get("dateEnd", ""),
          "milestones": project.get("milestones", ""),
          "type": project["types"][0]["type"] if project["types"] else "",
          "name": project["types"][0]["metrics"][0]["name"] if project["types"] and project["types"][0]["metrics"] else "",
          "value": project["types"][0]["metrics"][0]["value"] if project["types"] and project["types"][0]["metrics"] else "",
          "category": project.get("categories", ""),
          "image": project.get("image", ""),
          "imageCurrent": project.get("imageCurrent", ""),
          "imagesBefore": project.get("imagesBefore", ""),
          "kml": project.get("kml", ""),
          "additionalInformation": project.get("additionalInformation", ""),
          "additionalHtmlContent": project.get("additionalHtmlContent", ""),
    }
        flat_data.append(new_row)
    full_proj_count = json_data["count"]
    count = len(flat_data)
    return flat_data, count, json_data["next"]

# %%
start_url = "https://www.infravelo.de/api/v1/projects/"

# starter object that has no data attached
info = get_data_infravelo(start_url)

# iterate over the api pages
for i in range(44):
    info = get_data_infravelo(info[2], info[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 4
#       1 start_url = "https://www.infravelo.de/api/v1/projects/"
#       3 # starter object that has no data attached
# ----> 4 info = get_data_infravelo(start_url)
#       6 # iterate over the api pages
#       7 for i in range(44):
#
# Cell In[5], line 30, in get_data_infravelo(url, flat_data)
#       6 json_data = json.loads(response.read())
#       8 for project in json_data["results"]:
#       9     # Extract relevant information from each project dictionary
#      10     new_row = {
#      11       "id": project["id"],
#      12       "title": project["title"],
#      13       "subtitle": project.get("subtitle", ""),
#      14       "yearOfImplementation": project.get("yearOfImplementation", ""),  # Handle missing year
#      15       "status": project.get("status", ""),
#      16       "holder": project.get("holder", ""),
#      17       "costs": project.get("costs", ""),
#      18       "link": project.get("link", ""),
#      19       "apiLink": project.get("apiLink", ""),
#      20       "companyConstruction": project.get("companyConstruction", ""),
#      21       "owner": project.get("owner", ""),
#      22       "district": project["districts"][0]["name"] if project["districts"] else "",
#      23       "dateStart": project.get("dateStart", ""),
#      24       "dateEnd": project.get("dateEnd", ""),
#      25       "milestones": project.get("milestones", ""),
#      26       "type": project["types"][0]["type"] if project["types"] else "",
#      27       "name": project["types"][0]["metrics"][0]["name"] if project["types"] and project["types"][0]["metrics"] else "",
#      28       "value": project["types"][0]["metrics"][0]["value"] if project["types"] and project["types"][0]["metrics"] else "",
#      29       "category1": project["categories"][0]["name"] if project["categories"] and project["categories"][0] else "",
# ---> 30       "category2": project["categories"][1]["name"] if project["categories"] and project["categories"][1] else "",
#      31       "category3": project["categories"][2]["name"] if project["categories"] and project["categories"][2] else "",
#      32       "image": project.get("image", ""),
#      33       "imageCurrent": project.get("imageCurrent", ""),
#      34       "imagesBefore": project.get("imagesBefore", ""),
#      35       "kml": project.get("kml", ""),
#      36       "additionalInformation": project.get("additionalInformation", ""),
#      37       "additionalHtmlContent": project.get("additionalHtmlContent", ""),
#      38       # Extract data from nested dictionaries (types and districts)
#      39 }
#      40     # Append the new row to the flat_data list
#      41     flat_data.append(new_row)
#
# IndexError: list index out of range

# %%
proj_df = pd.json_normalize(info[0])
proj_df
# Out:
#               id                             title  \
# 0     9080038002  A-Schweitzer-Gymnasium Gymnasium
# 1     9100031042                 Adorfer Straße  8
# 2     9060111001                 Albrechtstraße 49
# 3     9060092029                 Albrechtstraße 81
# 4     9100031023          Alfred-Döblin-Straße 2 A
# ...          ...                               ...
# 2233      100349                   Schlüter­straße
# 2234      100087         Spandauer Damm – Freiheit
# 2235      100335                  Werbellin­straße
# 2236      100338                    Wichert­straße
# 2237      100340                    Wisbyer Straße
#
#                                                subtitle  yearOfImplementation  \
# 0                                                                      2020.0
# 1                                                                      2019.0
# 2                                                                      2023.0
# 3                                                                      2020.0
# 4                                                                      2019.0
# ...                                                 ...                   ...
# 2233  Sichtbarer mit dem Rad durch Einkaufsstraße im...                   NaN
# 2234  Unterwegs vom S-Bahnhof Westend bis in die Spa...                   NaN
# 2235  Sichtbar und sicherer zwischen Karl-Marx-Straß...                   NaN
# 2236  Wohn- und Schulkiez-Radfahrstreifen breiter un...                   NaN
# 2237  Sichtbarer und sicherer im Norden vom Prenzlau...                   NaN
#
#              status                                             holder costs  \
# 0     Abgeschlossen  Bezirksamt Neukölln finanziert durch Landesmit...
# 1     Abgeschlossen  Bezirksamt Marzahn-Hellersdorf finanziert durc...
# 2     Abgeschlossen  Bezirksamt Steglitz-Zehlendorf finanziert durc...
# 3     Abgeschlossen  Bezirksamt Steglitz-Zehlendorf finanziert durc...
# 4     Abgeschlossen  Bezirksamt Marzahn-Hellersdorf finanziert durc...
# ...             ...                                                ...   ...
# 2233  Abgeschlossen  Senatsverwaltung für Mobilität, Verkehr, Klima...
# 2234           None  Senatsverwaltung für Mobilität, Verkehr, Klima...
# 2235  Abgeschlossen  Senatsverwaltung für Mobilität, Verkehr, Klima...
# 2236  Abgeschlossen  Senatsverwaltung für Mobilität, Verkehr, Klima...
# 2237  Abgeschlossen  Senatsverwaltung für Mobilität, Verkehr, Klima...
#
#                                                    link  \
# 0     https://www.infravelo.de/projekt/a-schweitzer-...
# 1     https://www.infravelo.de/projekt/adorfer-stras...
# 2     https://www.infravelo.de/projekt/albrechtstras...
# 3     https://www.infravelo.de/projekt/albrechtstras...
# 4     https://www.infravelo.de/projekt/alfred-doebli...
# ...                                                 ...
# 2233  https://www.infravelo.de/projekt/schlueterstra...
# 2234  https://www.infravelo.de/projekt/spandauer-dam...
# 2235  https://www.infravelo.de/projekt/werbellinstra...
# 2236   https://www.infravelo.de/projekt/wichertstrasse/
# 2237  https://www.infravelo.de/projekt/wisbyer-strasse/
#
#                                                 apiLink  \
# 0     https://www.infravelo.de/api/v1/project/908003...
# 1     https://www.infravelo.de/api/v1/project/910003...
# 2     https://www.infravelo.de/api/v1/project/906011...
# 3     https://www.infravelo.de/api/v1/project/906009...
# 4     https://www.infravelo.de/api/v1/project/910003...
# ...                                                 ...
# 2233    https://www.infravelo.de/api/v1/project/100349/
# 2234    https://www.infravelo.de/api/v1/project/100087/
# 2235    https://www.infravelo.de/api/v1/project/100335/
# 2236    https://www.infravelo.de/api/v1/project/100338/
# 2237    https://www.infravelo.de/api/v1/project/100340/
#
#           companyConstruction  ...       value  \
# 0                              ...          30
# 1                              ...           6
# 2                              ...           4
# 3                              ...          16
# 4                              ...           8
# ...                       ...  ...         ...
# 2233  Possehl Spezialbau GmbH  ...  Beidseitig
# 2234                           ...
# 2235  Possehl Spezialbau GmbH  ...  Beidseitig
# 2236  Possehl Spezialbau GmbH  ...  Beidseitig
# 2237  Possehl Spezialbau GmbH  ...  Beidseitig
#
#                                   categories image imageCurrent  \
# 0                                         []   NaN
# 1                                         []   NaN
# 2                                         []   NaN
# 3                                         []   NaN
# 4                                         []   NaN
# ...                                      ...   ...          ...
# 2233       [{'name': 'Grün­be­schich­tung'}]   NaN
# 2234  [{'name': 'Rad­schnell­ver­bin­dung'}]   NaN
# 2235       [{'name': 'Grün­be­schich­tung'}]   NaN
# 2236       [{'name': 'Grün­be­schich­tung'}]   NaN
# 2237       [{'name': 'Grün­be­schich­tung'}]   NaN
#
#                                            imagesBefore  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 2233  [{'uri': 'https://www.infravelo.de/fileadmin/p...
# 2234  [{'uri': 'https://www.infravelo.de/fileadmin/p...
# 2235                                                 []
# 2236  [{'uri': 'https://www.infravelo.de/fileadmin/p...
# 2237  [{'uri': 'https://www.infravelo.de/fileadmin/p...
#
#                                                     kml additionalInformation  \
# 0     <?xml version="1.0" encoding="utf-8"?>\n<kml x...                    []
# 1     <?xml version="1.0" encoding="utf-8"?>\n<kml x...                    []
# 2     <?xml version="1.0" encoding="utf-8"?>\n<kml x...                    []
# 3     <?xml version="1.0" encoding="utf-8"?>\n<kml x...                    []
# 4     <?xml version="1.0" encoding="utf-8"?>\n<kml x...                    []
# ...                                                 ...                   ...
# 2233  <?xml version="1.0" encoding="utf-8"?>\n<kml x...                    []
# 2234                                                                       []
# 2235  <?xml version="1.0" encoding="utf-8"?>\n<kml x...                    []
# 2236  <?xml version="1.0" encoding="utf-8"?>\n<kml x...                    []
# 2237  <?xml version="1.0" encoding="utf-8"?>\n<kml x...                    []
#
#                                   additionalHtmlContent  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 2233                                                 []
# 2234  [\n\n<section class="accordion-section ">\n   ...
# 2235                                                 []
# 2236                                                 []
# 2237                                                 []
#
#                                               image.uri  image.extension
# 0                                                   NaN              NaN
# 1                                                   NaN              NaN
# 2                                                   NaN              NaN
# 3                                                   NaN              NaN
# 4                                                   NaN              NaN
# ...                                                 ...              ...
# 2233  https://www.infravelo.de/fileadmin/projektbild...              jpg
# 2234  https://www.infravelo.de/fileadmin/projektbild...              jpg
# 2235  https://www.infravelo.de/fileadmin/projektbild...              jpg
# 2236  https://www.infravelo.de/fileadmin/projektbild...              jpg
# 2237  https://www.infravelo.de/fileadmin/projektbild...              jpg
#
# [2238 rows x 27 columns]

# %%
proj_df.to_csv("infravelo_projects_raw.csv",index = False)
