# %%
import os
import geopandas as gpd
import pandas as pd
from shapely.wkt import loads
import matplotlib.pyplot as plt
import geoplot as gplt
import numpy as np

# %%
# import data
current_dir = os.getcwd()

# Construct the path to the 'data' directory relative to the current directory
data_dir = os.path.join(current_dir, '..', 'data')

# Access a specific file
df = pd.read_csv(os.path.join(data_dir, 'Bikeroad_Location+weight.csv'), low_memory = False)
streetmiss_df = pd.read_csv(os.path.join(data_dir, 'Missing_Streetnames_Map.csv'), low_memory = False)
parking_df = pd.read_csv(os.path.join(data_dir, 'Parking_Location.csv'), low_memory = False)

# %%
df.head()
# Out:
#        highway  lanes  lit maxspeed           streetname oneway  ref  \
# 0  residential    NaN  yes      NaN  AEG-Siedlung Heimat    NaN  NaN
# 1  residential    NaN  yes       30  AEG-Siedlung Heimat    NaN  NaN
# 2  residential    NaN  yes       30      Aachener Straße    NaN  NaN
# 3  residential    NaN  yes       30      Aachener Straße    NaN  NaN
# 4  residential    NaN  yes       30      Aachener Straße    NaN  NaN
#
#   smoothness                                           geometry  id link  \
# 0        NaN  LINESTRING (13.3478331 52.6098004, 13.347076 5... NaN  NaN
# 1        NaN  LINESTRING (13.347866 52.608813, 13.347076 52.... NaN  NaN
# 2        NaN  LINESTRING (13.3189287 52.4813095, 13.318873 5... NaN  NaN
# 3        NaN  LINESTRING (13.3183653 52.4789371, 13.3181786 ... NaN  NaN
# 4        NaN  LINESTRING (13.3155418 52.4796441, 13.3155083 ... NaN  NaN
#
#   district type name value function location    weight
# 0      NaN  NaN  NaN   NaN      NaN      NaN  1.695238
# 1      NaN  NaN  NaN   NaN      NaN      NaN  2.036508
# 2      NaN  NaN  NaN   NaN      NaN      NaN  2.036508
# 3      NaN  NaN  NaN   NaN      NaN      NaN  2.036508
# 4      NaN  NaN  NaN   NaN      NaN      NaN  2.036508

# %%
df[df["geometry"].isnull()]
# Out:
#       highway  lanes  lit maxspeed  \
# 1210      NaN    NaN  NaN      NaN
# 1479      NaN    NaN  NaN      NaN
# 3889      NaN    NaN  NaN      NaN
# 4408      NaN    NaN  NaN      NaN
# 5414      NaN    NaN  NaN      NaN
# ...       ...    ...  ...      ...
# 61517     NaN    NaN  NaN      NaN
# 62909     NaN    NaN  NaN      NaN
# 63595     NaN    NaN  NaN      NaN
# 63627     NaN    NaN  NaN      NaN
# 63925     NaN    NaN  NaN      NaN
#
#                                               streetname oneway  ref  \
# 1210                              Allee der Kosmo­nauten    NaN  NaN
# 1479                                Alt-Friedrichs­felde    NaN  NaN
# 3889                                        Am Wiesenweg    NaN  NaN
# 4408                      An der Wuhl­heide (Nord­seite)    NaN  NaN
# 5414                              B96a (Ad­ler­ge­stell)    NaN  NaN
# ...                                                  ...    ...  ...
# 61517                                     Wichert­straße    NaN  NaN
# 62909                                        Wuhletalweg    NaN  NaN
# 63595                                    Zionskirchplatz    NaN  NaN
# 63627                                    Zobtener Straße    NaN  NaN
# 63925  Zwischen Margaretenhöhe und Wartenberger Feldmark    NaN  NaN
#
#       smoothness geometry         id  \
# 1210         NaN      NaN   100426.0
# 1479         NaN      NaN   100347.0
# 3889         NaN      NaN  9090042.0
# 4408         NaN      NaN  9090017.0
# 5414         NaN      NaN  9090075.0
# ...          ...      ...        ...
# 61517        NaN      NaN   100338.0
# 62909        NaN      NaN  9100033.0
# 63595        NaN      NaN  9010035.0
# 63627        NaN      NaN  9110045.0
# 63925        NaN      NaN  9110037.0
#
#                                                     link             district  \
# 1210   https://www.infravelo.de/projekt/allee-der-kos...  Marzahn-Hellersdorf
# 1479   https://www.infravelo.de/projekt/alt-friedrich...          Lichtenberg
# 3889      https://www.infravelo.de/projekt/am-wiesenweg/     Treptow-Köpenick
# 4408   https://www.infravelo.de/projekt/an-der-wuhlhe...     Treptow-Köpenick
# 5414   https://www.infravelo.de/projekt/b96a-adlerges...     Treptow-Köpenick
# ...                                                  ...                  ...
# 61517   https://www.infravelo.de/projekt/wichertstrasse/               Pankow
# 62909      https://www.infravelo.de/projekt/wuhletalweg/  Marzahn-Hellersdorf
# 63595  https://www.infravelo.de/projekt/zionskirchplatz/                Mitte
# 63627  https://www.infravelo.de/projekt/zobtener-stra...          Lichtenberg
# 63925  https://www.infravelo.de/projekt/zwischen-marg...          Lichtenberg
#
#                               type              name       value function  \
# 1210         Grüner Seitenstreifen      Straßenseite  Beidseitig     road
# 1479         Grüner Seitenstreifen      Straßenseite         Ost     road
# 3889   Gemeinsamer Geh- und Radweg     Streckenlänge       157 m     road
# 4408                Schutzstreifen     Streckenlänge     3.267 m     road
# 5414   Geschützter Radfahrstreifen     Streckenlänge        80 m     road
# ...                            ...               ...         ...      ...
# 61517        Grüner Seitenstreifen      Straßenseite  Beidseitig     road
# 62909  Gemeinsamer Geh- und Radweg     Streckenlänge       897 m     road
# 63595        Verkehrsbeschilderung  Anzahl Wegweiser           2     road
# 63627                Fahrradstraße            Fläche      250 m²     road
# 63925                 Mischverkehr     Streckenlänge       175 m     road
#
#                                            location    weight
# 1210                  POINT (52.5258556 13.5193002)  0.996825
# 1479                  POINT (52.5095197 13.5189715)  0.996825
# 3889   POINT (52.41289493470502 13.568773775532323)  0.996825
# 4408                                            NaN  0.996825
# 5414                                            NaN  0.996825
# ...                                             ...       ...
# 61517                  POINT (52.5470187 13.424838)  0.996825
# 62909                                           NaN  0.996825
# 63595         POINT (52.5346033 13.403797262217864)  0.996825
# 63627                 POINT (52.4990881 13.4849141)  0.996825
# 63925                                           NaN  0.996825
#
# [99 rows x 18 columns]

# %%
# remove all rows where there's no location info
df = df[df["geometry"].notnull()]

# %%
# transform to geopandas format to display
df['geometry'] = df['geometry'].apply(loads)
df.head()
# Out:
#        highway  lanes  lit maxspeed           streetname oneway  ref  \
# 0  residential    NaN  yes      NaN  AEG-Siedlung Heimat    NaN  NaN
# 1  residential    NaN  yes       30  AEG-Siedlung Heimat    NaN  NaN
# 2  residential    NaN  yes       30      Aachener Straße    NaN  NaN
# 3  residential    NaN  yes       30      Aachener Straße    NaN  NaN
# 4  residential    NaN  yes       30      Aachener Straße    NaN  NaN
#
#   smoothness                                           geometry  id link  \
# 0        NaN  LINESTRING (13.3478331 52.6098004, 13.347076 5... NaN  NaN
# 1        NaN  LINESTRING (13.347866 52.608813, 13.347076 52.... NaN  NaN
# 2        NaN  LINESTRING (13.3189287 52.4813095, 13.318873 5... NaN  NaN
# 3        NaN  LINESTRING (13.3183653 52.4789371, 13.3181786 ... NaN  NaN
# 4        NaN  LINESTRING (13.3155418 52.4796441, 13.3155083 ... NaN  NaN
#
#   district type name value function location    weight
# 0      NaN  NaN  NaN   NaN      NaN      NaN  1.695238
# 1      NaN  NaN  NaN   NaN      NaN      NaN  2.036508
# 2      NaN  NaN  NaN   NaN      NaN      NaN  2.036508
# 3      NaN  NaN  NaN   NaN      NaN      NaN  2.036508
# 4      NaN  NaN  NaN   NaN      NaN      NaN  2.036508

# %%
gdf = gpd.GeoDataFrame(df, crs='epsg:4326')

# %%
fig, ax = plt.subplots()
sub_gdf = gdf[gdf["highway"].isin(["primary","secondary"])]
sub_gdf[sub_gdf['function'] == "road"].plot(color="green", ax=ax, zorder = 2) 
sub_gdf[sub_gdf['function'].isnull()].plot(color="orange", ax=ax, zorder = 1) 

plt.legend(['Bike-friendly street', 'No Biking Infrastructure'])

plt.show()

# %%
gdf[gdf["function"] == "road"]
# Out:
#            highway  lanes  lit maxspeed       streetname oneway    ref  \
# 141      secondary    2.0  yes     60.0     Adlergestell    yes    NaN
# 142        primary    3.0  yes     50.0     Adlergestell    yes  B 96a
# 143        primary    3.0  NaN     50.0     Adlergestell    yes  B 96a
# 144        primary    4.0  NaN     50.0     Adlergestell    yes  B 96a
# 145        primary    1.0  yes     50.0     Adlergestell    yes    NaN
# ...            ...    ...  ...      ...              ...    ...    ...
# 63568  residential    NaN  yes       30  Zingster Straße    NaN    NaN
# 63569  residential    1.0  yes       30  Zingster Straße    NaN    NaN
# 63570     tertiary    2.0  yes       30  Zingster Straße    NaN    NaN
# 63571     tertiary    2.0  yes       50  Zingster Straße    NaN    NaN
# 63572  residential    NaN  yes       30  Zingster Straße    NaN    NaN
#
#          smoothness                                           geometry  \
# 141            good  LINESTRING (13.62467 52.39004, 13.62481 52.389...
# 142             NaN  LINESTRING (13.55559 52.42586, 13.55507 52.42621)
# 143             NaN  LINESTRING (13.55486 52.42618, 13.55506 52.426...
# 144             NaN  LINESTRING (13.55739 52.42446, 13.55752 52.424...
# 145             NaN  LINESTRING (13.54896 52.43012, 13.54915 52.430...
# ...             ...                                                ...
# 63568  intermediate  LINESTRING (13.49526 52.57376, 13.49682 52.57443)
# 63569  intermediate  LINESTRING (13.49749 52.57383, 13.49806 52.57335)
# 63570           NaN  LINESTRING (13.49692 52.57008, 13.49705 52.569...
# 63571  intermediate  LINESTRING (13.49869 52.56855, 13.49881 52.56844)
# 63572           NaN  LINESTRING (13.50256 52.56525, 13.50263 52.56528)
#
#               id                                               link  \
# 141    9090039.0     https://www.infravelo.de/projekt/adlergestell/
# 142    9090039.0     https://www.infravelo.de/projekt/adlergestell/
# 143    9090039.0     https://www.infravelo.de/projekt/adlergestell/
# 144    9090039.0     https://www.infravelo.de/projekt/adlergestell/
# 145    9090039.0     https://www.infravelo.de/projekt/adlergestell/
# ...          ...                                                ...
# 63568  9110079.0  https://www.infravelo.de/projekt/zingster-stra...
# 63569  9110079.0  https://www.infravelo.de/projekt/zingster-stra...
# 63570  9110079.0  https://www.infravelo.de/projekt/zingster-stra...
# 63571  9110079.0  https://www.infravelo.de/projekt/zingster-stra...
# 63572  9110079.0  https://www.infravelo.de/projekt/zingster-stra...
#
#                district                         type           name  value  \
# 141    Treptow-Köpenick  Geschützter Radfahrstreifen  Streckenlänge  945 m
# 142    Treptow-Köpenick  Geschützter Radfahrstreifen  Streckenlänge  945 m
# 143    Treptow-Köpenick  Geschützter Radfahrstreifen  Streckenlänge  945 m
# 144    Treptow-Köpenick  Geschützter Radfahrstreifen  Streckenlänge  945 m
# 145    Treptow-Köpenick  Geschützter Radfahrstreifen  Streckenlänge  945 m
# ...                 ...                          ...            ...    ...
# 63568       Lichtenberg    Baulich getrennter Radweg  Streckenlänge  299 m
# 63569       Lichtenberg    Baulich getrennter Radweg  Streckenlänge  299 m
# 63570       Lichtenberg    Baulich getrennter Radweg  Streckenlänge  299 m
# 63571       Lichtenberg    Baulich getrennter Radweg  Streckenlänge  299 m
# 63572       Lichtenberg    Baulich getrennter Radweg  Streckenlänge  299 m
#
#       function                        location    weight
# 141       road  POINT (52.4273954 13.55306775)  1.107937
# 142       road  POINT (52.4273954 13.55306775)  1.163492
# 143       road  POINT (52.4273954 13.55306775)  1.163492
# 144       road  POINT (52.4273954 13.55306775)  1.330159
# 145       road  POINT (52.4273954 13.55306775)  0.687302
# ...        ...                             ...       ...
# 63568     road   POINT (52.5656901 13.5007932)  0.917460
# 63569     road   POINT (52.5656901 13.5007932)  0.750794
# 63570     road   POINT (52.5656901 13.5007932)  0.774603
# 63571     road   POINT (52.5656901 13.5007932)  1.139683
# 63572     road   POINT (52.5656901 13.5007932)  0.893651
#
# [4534 rows x 18 columns]

# %%
fig, ax = plt.subplots()
sub_gdf = gdf[gdf["highway"].isin(["tertiary","residential"])]
sub_gdf[sub_gdf['function'] == "road"].plot(color="green", ax=ax, zorder = 2) 
sub_gdf[sub_gdf['function'].isnull()].plot(color="orange", ax=ax, zorder = 1) 

plt.legend(['Bike-friendly street', 'No Biking Infrastructure'])

plt.show()

# %%
# plot missing streets
streetmiss_df['geometry'] = streetmiss_df['geometry'].apply(loads)
gdf2 = gpd.GeoDataFrame(streetmiss_df, crs='epsg:4326')
gdf2.plot()
# Out:
# <Axes: >

# %%
gdf[gdf["streetname"] == "Aachener Straße"].plot()
# Out:
# <Axes: >

# %%
len(gdf[gdf['streetname'] == "Aachener Straße"])
# Out:
# 14

# %%
parking_df.head()
# Out:
#            id                      title  \
# 0  9100031042          Adorfer Straße  8
# 1  9060111001          Albrechtstraße 49
# 2  9060092029          Albrechtstraße 81
# 3  9100031023   Alfred-Döblin-Straße 2 A
# 4  9100031051  Allee der Kosmonauten  79
#
#                                                 link             district  \
# 0  https://www.infravelo.de/projekt/adorfer-stras...  Marzahn-Hellersdorf
# 1  https://www.infravelo.de/projekt/albrechtstras...  Steglitz-Zehlendorf
# 2  https://www.infravelo.de/projekt/albrechtstras...  Steglitz-Zehlendorf
# 3  https://www.infravelo.de/projekt/alfred-doebli...  Marzahn-Hellersdorf
# 4  https://www.infravelo.de/projekt/allee-der-kos...  Marzahn-Hellersdorf
#
#           type                name  value function  \
# 0  Anlehnbügel  Anzahl Stellplätze      6  parking
# 1  Anlehnbügel  Anzahl Stellplätze      4  parking
# 2  Anlehnbügel  Anzahl Stellplätze     16  parking
# 3  Anlehnbügel  Anzahl Stellplätze      8  parking
# 4  Anlehnbügel  Anzahl Stellplätze      8  parking
#
#                         geometry
# 0  POINT (52.5320026 13.6072718)
# 1  POINT (52.4483762 13.3391646)
# 2  POINT (52.4494241 13.3384682)
# 3  POINT (52.5521667 13.5512789)
# 4  POINT (52.5279046 13.5460889)

# %%
def swap_coordinates(point_str):
  """
  Swaps the order of coordinates in a POINT string.

  Args:
    point_str: A string representing a point in the format "POINT (latitude longitude)".

  Returns:
    A string representing the point with swapped coordinates: "POINT (longitude latitude)".
  """
  try:
    # Extract coordinates from the string
    latlon = point_str.replace("POINT (", "").replace(")", "").split(" ")
    lat = latlon[0]
    lon = latlon[1]
    # Swap coordinates
    swapped_point = f"POINT ({lon} {lat})"
    return swapped_point
  except ValueError:
    print(f"Invalid point string: {point_str}")
    return None

parking_df['geometry'] = parking_df['geometry'].apply(swap_coordinates)
parking_df.head()
# Out:
#            id                      title  \
# 0  9100031042          Adorfer Straße  8
# 1  9060111001          Albrechtstraße 49
# 2  9060092029          Albrechtstraße 81
# 3  9100031023   Alfred-Döblin-Straße 2 A
# 4  9100031051  Allee der Kosmonauten  79
#
#                                                 link             district  \
# 0  https://www.infravelo.de/projekt/adorfer-stras...  Marzahn-Hellersdorf
# 1  https://www.infravelo.de/projekt/albrechtstras...  Steglitz-Zehlendorf
# 2  https://www.infravelo.de/projekt/albrechtstras...  Steglitz-Zehlendorf
# 3  https://www.infravelo.de/projekt/alfred-doebli...  Marzahn-Hellersdorf
# 4  https://www.infravelo.de/projekt/allee-der-kos...  Marzahn-Hellersdorf
#
#           type                name  value function  \
# 0  Anlehnbügel  Anzahl Stellplätze      6  parking
# 1  Anlehnbügel  Anzahl Stellplätze      4  parking
# 2  Anlehnbügel  Anzahl Stellplätze     16  parking
# 3  Anlehnbügel  Anzahl Stellplätze      8  parking
# 4  Anlehnbügel  Anzahl Stellplätze      8  parking
#
#                         geometry
# 0  POINT (13.6072718 52.5320026)
# 1  POINT (13.3391646 52.4483762)
# 2  POINT (13.3384682 52.4494241)
# 3  POINT (13.5512789 52.5521667)
# 4  POINT (13.5460889 52.5279046)

# %%
parking_df['geometry'] = parking_df['geometry'].apply(loads)
gdf2 = gpd.GeoDataFrame(parking_df, crs='epsg:4326')
gdf2.plot()
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots() 
gdf2.plot(ax=ax, color='red', markersize=10, marker='^', zorder = 3) 
sub_gdf = gdf[gdf["highway"].isin(["primary","secondary"])]
sub_gdf[sub_gdf['function'] == "road"].plot(color="green", ax=ax, zorder = 2) 
sub_gdf[sub_gdf['function'].isnull()].plot(color="orange", ax=ax, zorder = 1)

plt.legend(['Bike Parking', 'Bike-friendly Street', 'No Biking Infrastructure'])

plt.show()

# %%
gdf['weight'].unique()
# Out:
# array([1.6952381 , 2.03650794, 2.21904762, 2.06031746, 1.77460317,
#        1.91746032, 1.9968254 , 2.16349206, 1.48888889, 2.10793651,
#        1.10793651, 1.16349206, 1.33015873, 0.68730159, 1.13968254,
#        0.9968254 , 1.30634921, 0.90952381, 1.21904762, 1.07619048,
#        0.83015873, 0.94126984, 1.4968254 , 1.24285714, 0.71111111,
#        0.89365079, 0.91746032, 1.60793651, 1.93333333, 1.75079365,
#        1.71111111, 1.87777778, 1.26666667, 1.89365079, 2.27460317,
#        1.86190476, 2.26666667, 2.04444444, 1.82222222, 1.38571429,
#        1.32222222, 1.94126984, 1.83015873, 1.63968254, 2.33015873,
#        2.42539683, 2.21111111, 2.4968254 , 2.08412698, 2.30634921,
#        1.97301587, 0.77460317, 1.25079365, 1.44126984, 1.27460317,
#        2.13968254, 2.28253968, 2.44126984, 1.92539683, 1.96507937,
#        2.25079365, 2.61587302, 2.11587302, 2.48888889, 2.32222222,
#        2.24285714, 2.47301587, 1.78253968, 2.27460317, 1.54444444,
#        2.38571429, 1.71904762, 1.66349206, 2.1       , 1.76666667,
#        0.48888889, 1.52857143, 1.65555556, 2.55238095, 2.66349206,
#        0.60793651, 1.37777778, 2.22698413, 1.83809524, 2.41746032,
#        1.55238095, 0.32222222, 1.04444444, 1.40952381, 0.87777778,
#        1.36984127, 1.06031746, 2.36190476, 2.05238095, 2.26666667,
#        1.98888889, 0.65555556, 1.47301587, 1.63968254, 0.75079365,
#        2.2031746 , 0.54444444, 2.17936508, 2.40952381, 2.17142857,
#        2.37777778, 1.28253968, 1.27460317, 0.82222222, 2.15555556,
#        2.58412698, 2.55238095, 1.98095238, 2.56031746, 0.96507937,
#        1.21111111, 1.66349206, 1.37777778, 1.55238095, 2.6952381 ,
#        2.63968254, 2.60793651, 2.25079365, 1.25079365, 1.44920635,
#        0.98888889, 1.61587302, 0.97301587, 0.93333333, 1.08412698,
#        1.53650794, 2.44920635, 2.83015873, 2.80634921, 2.02063492])

# %%
sub_gdf = gdf[gdf["highway"].isin(["primary","secondary"])]
sub_gdf.plot(column='weight', cmap='viridis', legend=True, figsize=(10, 6)) 

plt.xlabel('Longitude')
plt.ylabel('Latitude')

# Show the plot
plt.show()
